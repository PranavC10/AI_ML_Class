# %% [markdown]
# # What is SQL?
# SQL stands for Structured Query Language
#
# SQL lets you access and manipulate databases
#
# Install : pip install mysql-connector-python  or  conda install -c conda-forge mysql-connector-python

# %% [markdown]
# # As a data analyst / Scientist, you will primarily need to read data from the database .¶
# Steps to follow :
# Create connection
#
# Create cursor
#
# Create Query string
#
# Execute the query
#
# Close the connection

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as connection ##
import pandas as pd
try:
    mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True) ## passwd add your password
    # check if the connection is established
    print(mydb.is_connected())
    mydb.close()
    
except Exception as e:
    print(str(e))
# Out:
# True

# %%
def sql(query,db="practise_data"):
    try:
        mydb = connection.connect(host="localhost", database = db,user="root", passwd="mysql",use_pure=True) ## connection
    # check if the connection is established
        #print(mydb.is_connected())
        result_dataFrame = pd.read_sql(query,mydb) ## pandas can read sql
        return result_dataFrame
        mydb.close()
    except Exception as e:
        mydb.close()
        print(str(e))

# %%
sql("show tables") ## show all the tables in the database (DB)
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   Tables_in_practise_data
# 0                  agents
# 1                 company
# 2                customer
# 3               daysorder
# 4                despatch
# 5                   foods
# 6              listofitem
# 7                  orders
# 8                 student
# 9           studentreport

# %%
df=sql("select * from customer") ## select * (means all the cols) from customer
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df.head()
# Out:
#   CUST_CODE  CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00013     Holmes  London                                    London
# 1    C00001    Micheal  New York                                New York
# 2    C00020     Albert  New York                                New York
# 3    C00025  Ravindran  Bangalore                              Bangalore
# 4    C00024       Cook  London                                    London
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0           UK    2.0       6000.0       5000.0       7000.0           4000.0
# 1          USA    2.0       3000.0       5000.0       2000.0           6000.0
# 2          USA    3.0       5000.0       7000.0       6000.0           6000.0
# 3        India    2.0       5000.0       7000.0       4000.0           8000.0
# 4           UK    2.0       4000.0       9000.0       7000.0           6000.0
#
#   PHONE_NO AGENT_CODE
# 0  BBBBBBB     A003
# ...

# %%
df.shape
# Out:
# (25, 12)

# %% [markdown]
# ## Print or view the data of food table

# %%
sql(r"select * from foods")
# Out:
#   ITEM_ID     ITEM_NAME ITEM_UNIT COMPANY_ID
# 0       1      Chex Mix       Pcs       16\r
# 1       6      Cheez-It       Pcs       15\r
# 2       2    BN Biscuit       Pcs       15\r
# 3       3  Mighty Munch       Pcs       17\r
# 4       4      Pot Rice       Pcs       15\r
# 5       5   Jaffa Cakes       Pcs       18\r
# 6       7  Salt n Shake       Pcs         \r

# %% [markdown]
# ## Storing the sql data in dataframe

# %%
food = sql(r"select * from foods")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
food
# Out:
#   ITEM_ID     ITEM_NAME ITEM_UNIT COMPANY_ID
# 0       1      Chex Mix       Pcs       16\r
# 1       6      Cheez-It       Pcs       15\r
# 2       2    BN Biscuit       Pcs       15\r
# 3       3  Mighty Munch       Pcs       17\r
# 4       4      Pot Rice       Pcs       15\r
# 5       5   Jaffa Cakes       Pcs       18\r
# 6       7  Salt n Shake       Pcs         \r

# %%
food.to_csv("Food.csv")

# %%
sql("select * from customer").head(2)
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00013    Holmes  London                                    London
# 1    C00001   Micheal  New York                                New York
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0           UK    2.0       6000.0       5000.0       7000.0           4000.0
# 1          USA    2.0       3000.0       5000.0       2000.0           6000.0
#
#   PHONE_NO AGENT_CODE
# 0  BBBBBBB     A003
# 1  CCCCCCC     A008

# %%
sql("select CUST_NAME,CUST_CITY from customer").head(2)
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_NAME                            CUST_CITY
# 0    Holmes  London
# 1   Micheal  New York

# %%
sql(r"select * from customer where CUST_CITY='Torento'") ## select col_names from table_name where condition
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00006   Shilton  Torento                                  Torento
# 1    C00008  Karolina  Torento                                  Torento
# 2    C00003    Martin  Torento                                  Torento
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0       Canada    1.0      10000.0       7000.0       6000.0          11000.0
# 1       Canada    1.0       7000.0       7000.0       9000.0           5000.0
# 2       Canada    2.0       8000.0       7000.0       7000.0           8000.0
#
#   PHONE_NO AGENT_CODE
# 0  DDDDDDD     A004
# 1  HJKORED     A004
# 2  MJYURFD     A004

# %%
cust = sql("select * from customer")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
## once you get the data in python using pandas. you can use all features of pandas because sql data is converted to pandas DF

# %%
cust[cust["RECEIVE_AMT"] > 5000]
# Out:
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 2     C00020       Albert  New York                                New York
# 3     C00025    Ravindran  Bangalore                              Bangalore
# 4     C00024         Cook  London                                    London
# 5     C00015       Stuart  London                                    London
# 6     C00002         Bolt  New York                                New York
# 7     C00018      Fleming  Brisban                                  Brisban
# 8     C00021        Jacks  Brisban                                  Brisban
# 9     C00019  Yearannaidu  Chennai                                  Chennai
# 10    C00005     Sasikant  Mumbai                                    Mumbai
# 11    C00007   Ramanathan  Chennai                                  Chennai
# 12    C00022      Avinash  Mumbai                                    Mumbai
# ...

# %%
sql(r"select * from customer where RECEIVE_AMT > 5000 ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00020       Albert  New York                                New York
# 1     C00025    Ravindran  Bangalore                              Bangalore
# 2     C00024         Cook  London                                    London
# 3     C00015       Stuart  London                                    London
# 4     C00002         Bolt  New York                                New York
# 5     C00018      Fleming  Brisban                                  Brisban
# 6     C00021        Jacks  Brisban                                  Brisban
# 7     C00019  Yearannaidu  Chennai                                  Chennai
# ...

# %%
sql(r"select * from customer where CUST_CITY='Bangalore'")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00025   Ravindran  Bangalore                              Bangalore
# 1    C00017    Srinivas  Bangalore                              Bangalore
# 2    C00014  Rangarappa  Bangalore                              Bangalore
# 3    C00016  Venkatpati  Bangalore                              Bangalore
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0        India    2.0       5000.0       7000.0       4000.0           8000.0
# 1        India    2.0       8000.0       4000.0       3000.0           9000.0
# 2        India    2.0       8000.0      11000.0       7000.0          12000.0
# ...

# %%
sql(r"select * from customer where CUST_CITY='Bangalore'and OPENING_AMT >5000")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00017    Srinivas  Bangalore                              Bangalore
# 1    C00014  Rangarappa  Bangalore                              Bangalore
# 2    C00016  Venkatpati  Bangalore                              Bangalore
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0        India    2.0       8000.0       4000.0       3000.0           9000.0
# 1        India    2.0       8000.0      11000.0       7000.0          12000.0
# 2        India    2.0       8000.0      11000.0       7000.0          12000.0
#
#   PHONE_NO AGENT_CODE
# 0  AAAAAAB     A007
# 1  AAAATGF     A001
# ...

# %%
sql(r"select CUST_COUNTRY  from customer")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_COUNTRY
# 0         India
# 1         India
# 2         India
# 3         India
# 4     Australia
# 5     Australia
# 6     Australia
# 7         India
# 8         India
# 9         India
# 10           UK
# 11           UK
# 12           UK
# 13           UK
# 14           UK
# 15        India
# 16        India
# 17        India
# 18          USA
# 19          USA
# 20          USA
# 21          USA
# 22       Canada
# 23       Canada
# 24       Canada

# %%
sql(r"select distinct CUST_COUNTRY  from customer") ## distinct gives unique records
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_COUNTRY
# 0        India
# 1    Australia
# 2           UK
# 3          USA
# 4       Canada

# %%
sql(r"select * from customer where OPENING_AMT between 5000 and 7000")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00013      Holmes  London                                    London
# 1     C00020      Albert  New York                                New York
# 2     C00025   Ravindran  Bangalore                              Bangalore
# 3     C00015      Stuart  London                                    London
# 4     C00002        Bolt  New York                                New York
# 5     C00018     Fleming  Brisban                                  Brisban
# 6     C00021       Jacks  Brisban                                  Brisban
# 7     C00005    Sasikant  Mumbai                                    Mumbai
# ...

# %%
sql(r"select * from customer where OPENING_AMT >= 5000 and OPENING_AMT <= 7000") ## it is same as above
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00013      Holmes  London                                    London
# 1     C00020      Albert  New York                                New York
# 2     C00025   Ravindran  Bangalore                              Bangalore
# 3     C00015      Stuart  London                                    London
# 4     C00002        Bolt  New York                                New York
# 5     C00018     Fleming  Brisban                                  Brisban
# 6     C00021       Jacks  Brisban                                  Brisban
# 7     C00005    Sasikant  Mumbai                                    Mumbai
# ...

# %%
sql(r"select * from customer where OPENING_AMT = 5000 or OPENING_AMT = 7000") ## give me the customers whose op_amount is 5000 or 7000
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00020      Albert  New York                                New York
# 1     C00025   Ravindran  Bangalore                              Bangalore
# 2     C00002        Bolt  New York                                New York
# 3     C00018     Fleming  Brisban                                  Brisban
# 4     C00021       Jacks  Brisban                                  Brisban
# 5     C00005    Sasikant  Mumbai                                    Mumbai
# 6     C00007  Ramanathan  Chennai                                  Chennai
# 7     C00022     Avinash  Mumbai                                    Mumbai
# ...

# %%
sql(r"select * from customer where not  PAYMENT_AMT = 7000") ## get me cust whose pay_amt is not 7000
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00001     Micheal  New York                                New York
# 1     C00020      Albert  New York                                New York
# 2     C00025   Ravindran  Bangalore                              Bangalore
# 3     C00015      Stuart  London                                    London
# 4     C00002        Bolt  New York                                New York
# 5     C00018     Fleming  Brisban                                  Brisban
# 6     C00007  Ramanathan  Chennai                                  Chennai
# 7     C00022     Avinash  Mumbai                                    Mumbai
# ...

# %%
sql(r"select * from customer where  PAYMENT_AMT != 7000")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00001     Micheal  New York                                New York
# 1     C00020      Albert  New York                                New York
# 2     C00025   Ravindran  Bangalore                              Bangalore
# 3     C00015      Stuart  London                                    London
# 4     C00002        Bolt  New York                                New York
# 5     C00018     Fleming  Brisban                                  Brisban
# 6     C00007  Ramanathan  Chennai                                  Chennai
# 7     C00022     Avinash  Mumbai                                    Mumbai
# ...

# %%
sql("select * from customer order by GRADE ,OPENING_AMT") ## first it will sort on Grade then opening amt
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00023         Karl  London                                    London
# 1     C00004      Winston  Brisban                                  Brisban
# 2     C00012       Steven  San Jose                                San Jose
# 3     C00015       Stuart  London                                    London
# 4     C00021        Jacks  Brisban                                  Brisban
# 5     C00005     Sasikant  Mumbai                                    Mumbai
# 6     C00007   Ramanathan  Chennai                                  Chennai
# 7     C00008     Karolina  Torento                                  Torento
# ...

# %%
sql("select * from customer order by GRADE ,OPENING_AMT,CUST_COUNTRY")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00023         Karl  London                                    London
# 1     C00004      Winston  Brisban                                  Brisban
# 2     C00012       Steven  San Jose                                San Jose
# 3     C00015       Stuart  London                                    London
# 4     C00021        Jacks  Brisban                                  Brisban
# 5     C00008     Karolina  Torento                                  Torento
# 6     C00005     Sasikant  Mumbai                                    Mumbai
# 7     C00007   Ramanathan  Chennai                                  Chennai
# ...

# %%
sql("select * from customer order by GRADE ,OPENING_AMT  desc") #asc for ascending order
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00023         Karl  London                                    London
# 1     C00006      Shilton  Torento                                  Torento
# 2     C00019  Yearannaidu  Chennai                                  Chennai
# 3     C00021        Jacks  Brisban                                  Brisban
# 4     C00005     Sasikant  Mumbai                                    Mumbai
# 5     C00007   Ramanathan  Chennai                                  Chennai
# 6     C00008     Karolina  Torento                                  Torento
# 7     C00015       Stuart  London                                    London
# ...

# %%
sql("select * from customer order by GRADE desc ,OPENING_AMT  asc") #asc for ascending order
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00020       Albert  New York                                New York
# 1     C00002         Bolt  New York                                New York
# 2     C00010      Charles  Hampshair                              Hampshair
# 3     C00011    Sundariya  Chennai                                  Chennai
# 4     C00009       Ramesh  Mumbai                                    Mumbai
# 5     C00001      Micheal  New York                                New York
# 6     C00024         Cook  London                                    London
# 7     C00025    Ravindran  Bangalore                              Bangalore
# ...

# %%
sql("select * from customer order by GRADE asc ,OPENING_AMT  desc")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00023         Karl  London                                    London
# 1     C00006      Shilton  Torento                                  Torento
# 2     C00019  Yearannaidu  Chennai                                  Chennai
# 3     C00021        Jacks  Brisban                                  Brisban
# 4     C00005     Sasikant  Mumbai                                    Mumbai
# 5     C00007   Ramanathan  Chennai                                  Chennai
# 6     C00008     Karolina  Torento                                  Torento
# 7     C00015       Stuart  London                                    London
# ...

# %%
sql("select * from customer where OUTSTANDING_AMT is null")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [CUST_CODE, CUST_NAME, CUST_CITY, WORKING_AREA, CUST_COUNTRY, GRADE, OPENING_AMT, RECEIVE_AMT, PAYMENT_AMT, OUTSTANDING_AMT, PHONE_NO, AGENT_CODE]
# Index: []

# %%
sql("select * from customer where OUTSTANDING_AMT is not null")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    CUST_CODE    CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0     C00013       Holmes  London                                    London
# 1     C00001      Micheal  New York                                New York
# 2     C00020       Albert  New York                                New York
# 3     C00025    Ravindran  Bangalore                              Bangalore
# 4     C00024         Cook  London                                    London
# 5     C00015       Stuart  London                                    London
# 6     C00002         Bolt  New York                                New York
# 7     C00018      Fleming  Brisban                                  Brisban
# ...

# %%
sql("select   * from customer limit 3 ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00013    Holmes  London                                    London
# 1    C00001   Micheal  New York                                New York
# 2    C00020    Albert  New York                                New York
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0           UK    2.0       6000.0       5000.0       7000.0           4000.0
# 1          USA    2.0       3000.0       5000.0       2000.0           6000.0
# 2          USA    3.0       5000.0       7000.0       6000.0           6000.0
#
#   PHONE_NO AGENT_CODE
# 0  BBBBBBB     A003
# 1  CCCCCCC     A008
# 2  BBBBSBB     A008

# %%
sql("select min(PAYMENT_AMT)   from customer  ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    min(PAYMENT_AMT)
# 0            2000.0

# %%
sql("select max(PAYMENT_AMT)   from customer  ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    max(PAYMENT_AMT)
# 0            9000.0

# %%
sql("select avg(PAYMENT_AMT)   from customer  ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    avg(PAYMENT_AMT)
# 0            6520.0

# %%
sql("select sum(PAYMENT_AMT)   from customer  ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    sum(PAYMENT_AMT)
# 0          163000.0

# %%
sql("select * from customer where CUST_NAME like 'S%'  ")  ## Give me those customer whose name start with S ## % it can have any value
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE  CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00015     Stuart  London                                    London
# 1    C00005   Sasikant  Mumbai                                    Mumbai
# 2    C00006    Shilton  Torento                                  Torento
# 3    C00017   Srinivas  Bangalore                              Bangalore
# 4    C00012     Steven  San Jose                                San Jose
# 5    C00011  Sundariya  Chennai                                  Chennai
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0           UK    1.0       6000.0       8000.0       3000.0          11000.0
# ...

# %%
sql("select * from customer where CUST_NAME like '_t%'  ")  ## _ there can be single letter ... % means single or multiple letters
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00015    Stuart  London                                    London
# 1    C00012    Steven  San Jose                                San Jose
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0           UK    1.0       6000.0       8000.0       3000.0          11000.0
# 1          USA    1.0       5000.0       7000.0       9000.0           3000.0
#
#   PHONE_NO AGENT_CODE
# 0  GFSGERS     A003
# 1  KRFYGJK     A012

# %%
### I want customer whose name has 3rd letter should be u 
sql("select * from customer where CUST_NAME like '__u%'  ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00015    Stuart  London                                    London
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0           UK    1.0       6000.0       8000.0       3000.0          11000.0
#
#   PHONE_NO AGENT_CODE
# 0  GFSGERS     A003

# %%
sql("select * from customer where CUST_NAME like '%a'  ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE   CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00008    Karolina  Torento                                  Torento
# 1    C00014  Rangarappa  Bangalore                              Bangalore
# 2    C00011   Sundariya  Chennai                                  Chennai
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0       Canada    1.0       7000.0       7000.0       9000.0           5000.0
# 1        India    2.0       8000.0      11000.0       7000.0          12000.0
# 2        India    3.0       7000.0      11000.0       7000.0          11000.0
#
#   PHONE_NO AGENT_CODE
# 0  HJKORED     A004
# 1  AAAATGF     A001
# ...

# %%
sql("select * from customer where CUST_NAME like 'k%a'  ")
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CUST_CODE CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00008  Karolina  Torento                                  Torento
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0       Canada    1.0       7000.0       7000.0       9000.0           5000.0
#
#   PHONE_NO AGENT_CODE
# 0  HJKORED     A004

# %%
## Get me the customer whose OPENING_AMT is > 5000

## Get me the customer whose OPENING_AMT  is between 100 - 2000

## Get me the average grade of the customer

## get me the customer who are in  CUST_CITY San Jose	

## get me those customer whose name end with "na"

## get me those customer whose name start with s and second last letter is r
